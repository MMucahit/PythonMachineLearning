# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %% [markdown]
# Veri Okuma

# %%
dataFrame = pd.read_csv('maaslar.csv')
dataFrame.head() ## Verilere genel bakış(kolonları sütünları görmek için)
# Out:
#               unvan  Egitim Seviyesi  maas
# 0             Cayci                1  2250
# 1          Sekreter                2  2500
# 2  Uzman Yardimcisi                3  3000
# 3             Uzman                4  4000
# 4  Proje Yoneticisi                5  5500

# %% [markdown]
# Veriyi Anlamak

# %%
dataFrame.describe() ## Verinin istatistikleri
# Out:
#        Egitim Seviyesi          maas
# count         10.00000     10.000000
# mean           5.50000  12475.000000
# std            3.02765  14968.694183
# min            1.00000   2250.000000
# 25%            3.25000   3250.000000
# 50%            5.50000   6500.000000
# 75%            7.75000  13750.000000
# max           10.00000  50000.000000

# %%
dataFrame.isnull().sum() ## Null verilerin kontrolü
# Out:
# unvan              0
# Egitim Seviyesi    0
# maas               0
# dtype: int64

# %% [markdown]
# Grafiksel Analiz

# %%
plt.figure(figsize=(10,7)) ## exponansiyel(üstsel) artış
sbn.scatterplot(x='Egitim Seviyesi',y='maas',data=dataFrame) ## Noktasal grafik
# Out:
# <AxesSubplot:xlabel='Egitim Seviyesi', ylabel='maas'>

# %% [markdown]
# Model Oluşturma

# %%
y = dataFrame.iloc[:,2:3].values ## Maas
x = dataFrame.iloc[:,1:2].values ## Egitim seviyesi

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt_reg = DecisionTreeRegressor(random_state=0)
dt_reg.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
guess = dt_reg.predict(x) ## x_scale rgöre tahmin
guess ## Tahmin verisi
# Out:
# array([ 2250.,  2500.,  3000.,  4000.,  5500.,  7500., 10000., 15000.,
#        25000., 50000.])

# %%
plt.figure(figsize=(10,10))
plt.scatter(x,y)
plt.title('rbf')
plt.plot(x,guess,'g-*')

# %%
## DecisionTree nın kötü yanı 9.6 den buyuk her tahmın 50000

# %%
dt_reg.predict([[9.6]])
# Out:
# array([50000.])

# %%
dt_reg.predict([[25]])
# Out:
# array([50000.])

# %%
## DecisionTree nın kötü yanı 8.6 den buyuk ve 9.5 arası her tahmın 25000

# %%
dt_reg.predict([[8.6]])
# Out:
# array([25000.])

# %%
dt_reg.predict([[9.5]])
# Out:
# array([25000.])

# %%
## tahmın olarak maas tablosundakı degerlerden baska bır degerın gelme ıhtımalı yok
